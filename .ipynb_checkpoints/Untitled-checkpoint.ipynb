# %%
import requests
import json

# %%
def CallAllMatchesApi():
    url = "https://unofficial-cricbuzz.p.rapidapi.com/matches/list"

    querystring = {"matchState":"live"}

    headers = {
        'x-rapidapi-host': "unofficial-cricbuzz.p.rapidapi.com",
        'x-rapidapi-key': "1eab839b95mshd98f74f1e9e31f4p12c777jsn666802c72f65"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    respJson = json.loads(response.text)
    print(response.text)
    return respJson

# %%
jsonAllMatches=CallAllMatchesApi()
# Out:
# {
#   "typeMatches": [{
#     "matchType": "International",
#     "seriesAdWrapper": [{
#       "seriesMatches": {
#         "seriesId": 3936,
#         "seriesName": "Zimbabwe tour of Sri Lanka, 2022",
#         "matches": [{
#           "matchInfo": {
#             "matchId": 42381,
#             "seriesId": 3936,
#             "seriesName": "Zimbabwe tour of Sri Lanka, 2022",
#             "matchDesc": "2nd ODI",
#             "matchFormat": "ODI",
#             "startDate": "1642496400000",
#             "endDate": "1642525200000",
#             "state": "In Progress",
#             "status": "Zimbabwe opt to bat",
#             "team1": {
#               "teamId": 5,
#               "teamName": "Sri Lanka",
#               "teamSName": "SL",
#               "imageId": 172119
#             },
#             "team2": {
#               "teamId": 12,
#               "teamName": "Zimbabwe",
#               "teamSName": "ZIM",
#               "imageId": 172127
#             },
#             "venueInfo": {
#               "id": 254,
#               "ground": "Pallekele International Cricket Stadium",
#               "city": "Pallekele",
#               "timezone": "+05:30"
#             },
#             "currentBatTeamId": 12,
#             "seriesStartDt": "1642291200000",
#             "seriesEndDt": "1642896000000"
#           },
#           "matchScore": {
#             "team2Score": {
#               "inngs1": {
#                 "inningsId": 1,
#                 "runs": 66,
#                 "wickets": 1,
#                 "overs": 10.5
#               }
#             }
#           }
#         }]
#       }
#     }, {
#       "adDetail": {
#         "name": "native_matches",
#         "adLayout": "native_large",
#         "position": 1
#       }
#     }]
#   }, {
#     "matchType": "League",
#     "seriesAdWrapper": [{
#       "seriesMatches": {
#         "seriesId": 3836,
#         "seriesName": "Super Smash 2021-22",
#         "matches": [{
#           "matchInfo": {
#             "matchId": 39683,
#             "seriesId": 3836,
#             "seriesName": "Super Smash 2021-22",
#             "matchDesc": "25th Match",
#             "matchFormat": "T20",
#             "startDate": "1642484400000",
#             "endDate": "1642497000000",
#             "state": "Complete",
#             "status": "Canterbury won by 18 runs",
#             "team1": {
#               "teamId": 312,
#               "teamName": "Canterbury",
#               "teamSName": "CAN",
#               "imageId": 172362
#             },
#             "team2": {
#               "teamId": 186,
#               "teamName": "Auckland",
#               "teamSName": "AKL",
#               "imageId": 172246
#             },
#             "venueInfo": {
#               "id": 371,
#               "ground": "Hagley Oval",
#               "city": "Christchurch",
#               "timezone": "+13:00"
#             },
#             "currentBatTeamId": 312,
#             "seriesStartDt": "1637884800000",
#             "seriesEndDt": "1643587200000"
#           },
#           "matchScore": {
#             "team1Score": {
#               "inngs1": {
#                 "inningsId": 1,
#                 "runs": 154,
#                 "wickets": 10,
#                 "overs": 19.5
#               }
#             },
#             "team2Score": {
#               "inngs1": {
#                 "inningsId": 2,
#                 "runs": 136,
#                 "wickets": 7,
#                 "overs": 19.6
#               }
#             }
#           }
#         }]
#       }
#     }, {
#       "seriesMatches": {
#         "seriesId": 3576,
#         "seriesName": "Big Bash League 2021-22",
#         "matches": [{
#           "matchInfo": {
#             "matchId": 37176,
#             "seriesId": 3576,
#             "seriesName": "Big Bash League 2021-22",
#             "matchDesc": "54th Match",
#             "matchFormat": "T20",
#             "startDate": "1642493700000",
#             "endDate": "1642506300000",
#             "state": "Innings Break",
#             "status": "Innings Break",
#             "team1": {
#               "teamId": 194,
#               "teamName": "Hobart Hurricanes",
#               "teamSName": "HBH",
#               "imageId": 172254
#             },
#             "team2": {
#               "teamId": 195,
#               "teamName": "Melbourne Renegades",
#               "teamSName": "MLR",
#               "imageId": 172255
#             },
#             "venueInfo": {
#               "id": 33,
#               "ground": "Docklands Stadium",
#               "city": "Melbourne",
#               "timezone": "+11:00"
#             },
#             "currentBatTeamId": 194,
#             "seriesStartDt": "1638662400000",
#             "seriesEndDt": "1643500800000"
#           },
#           "matchScore": {
#             "team1Score": {
#               "inngs1": {
#                 "inningsId": 1,
#                 "runs": 182,
#                 "wickets": 5,
#                 "overs": 19.6
#               }
#             }
#           }
#         }]
#       }
#     }]
#   }],
#   "filters": {
#     "matchType": ["International", "League", "Domestic", "Women"]
#   },
#   "appIndex": {
#     "seoTitle": "Live Cricket Score - Scorecard and Match Results",
#     "webURL": "www.cricbuzz.com/live-cricket-scores/"
#   },
#   "responseLastUpdated": "1642499445"
# }

# %%
typeMatches=jsonAllMatches['']

# %%
AllMatches=[]
for match in typeMatches:
    if match['matchType'] == 'International' or match['matchType'] == 'League':
        seriesAdWrapper=match['seriesAdWrapper']
        for saw in seriesAdWrapper:
            if 'seriesMatches' in saw:
                seriesMatches= saw['seriesMatches']
                if 'matches' in seriesMatches:
                    matches= seriesMatches['matches']
                    for match in matches:
                        if 'matchInfo' in match:
                            matchInfo = match['matchInfo']
                            matchId= matchInfo['matchId']
                            team1= matchInfo['team1']
                            team2= matchInfo['team2']
                            MatchDic = {}
                            MatchDic['matchId']=matchId
                            MatchDic['team1Name']=team1['teamName']
                            MatchDic['team2Name']=team2['teamName']
                            MatchDic['vs']=team1['teamSName']+" vs "+team2['teamSName']
                            AllMatches.append(MatchDic)

# %%
AllMatches
# Out:
# [{'matchId': 42381,
#   'team1Name': 'Sri Lanka',
#   'team2Name': 'Zimbabwe',
#   'vs': 'SL vs ZIM'},
#  {'matchId': 39683,
#   'team1Name': 'Canterbury',
#   'team2Name': 'Auckland',
#   'vs': 'CAN vs AKL'},
#  {'matchId': 37176,
#   'team1Name': 'Hobart Hurricanes',
#   'team2Name': 'Melbourne Renegades',
#   'vs': 'HBH vs MLR'}]

# %%
selectedVs = 'SL vs ZIM'

# %%
def CallMatchDetailsApi(id):
    url = "https://unofficial-cricbuzz.p.rapidapi.com/matches/get-scorecard"

    querystring = {"matchId":id}

    headers = {
        'x-rapidapi-host': "unofficial-cricbuzz.p.rapidapi.com",
        'x-rapidapi-key': "1eab839b95mshd98f74f1e9e31f4p12c777jsn666802c72f65"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    print(response.text)
    return json.loads(response.text)

# %%
match=CallMatchDetailsApi('42381')
# Out:
# {
#   "scorecard": [{
#     "inningsId": 1,
#     "batsman": [{
#       "id": 19601,
#       "balls": 28,
#       "runs": 26,
#       "fours": 2,
#       "sixes": 1,
#       "strkRate": "92.86",
#       "name": "Takudzwanashe Kaitano",
#       "nickName": "Takudzwanashe Kaitano",
#       "outDec": " b Vandersay"
#     }, {
#       "id": 781,
#       "balls": 50,
#       "runs": 47,
#       "fours": 5,
#       "sixes": 1,
#       "strkRate": "94",
#       "name": "Regis Chakabva",
#       "nickName": "Chakabva",
#       "isKeeper": true,
#       "outDec": "st Kusal Mendis b Vandersay"
#     }, {
#       "id": 6334,
#       "balls": 23,
#       "runs": 17,
#       "fours": 2,
#       "strkRate": "73.91",
#       "name": "Craig Ervine",
#       "nickName": "Craig Ervine",
#       "isCaptain": true,
#       "outDec": "batting"
#     }, {
#       "id": 441,
#       "balls": 10,
#       "runs": 4,
#       "strkRate": "40",
#       "name": "Sean Williams",
#       "nickName": "Sean Williams",
#       "outDec": "batting"
#     }, {
#       "id": 11226,
#       "strkRate": "0",
#       "name": "Wesley Madhevere",
#       "nickName": "Madhevere"
#     }, {
#       "id": 9354,
#       "strkRate": "0",
#       "name": "Sikandar Raza",
#       "nickName": "Raza"
#     }, {
#       "id": 8454,
#       "strkRate": "0",
#       "name": "Ryan Burl",
#       "nickName": "Ryan Burl"
#     }, {
#       "id": 8460,
#       "strkRate": "0",
#       "name": "Wellington Masakadza",
#       "nickName": "W Masakadza"
#     }, {
#       "id": 13316,
#       "strkRate": "0",
#       "name": "Blessing Muzarabani",
#       "nickName": "Muzarabani"
#     }, {
#       "id": 6483,
#       "strkRate": "0",
#       "name": "Tendai Chatara",
#       "nickName": "Chatara"
#     }, {
#       "id": 11229,
#       "strkRate": "0",
#       "name": "Richard Ngarava",
#       "nickName": "Ngarava"
#     }],
#     "bowler": [{
#       "id": 6730,
#       "overs": "3",
#       "runs": 27,
#       "economy": "9",
#       "name": "Nuwan Pradeep",
#       "nickName": "N Pradeep"
#     }, {
#       "id": 8393,
#       "overs": "4",
#       "runs": 17,
#       "economy": "4.2",
#       "name": "Dushmantha Chameera",
#       "nickName": "Chameera"
#     }, {
#       "id": 8422,
#       "overs": "2",
#       "runs": 14,
#       "economy": "7",
#       "name": "Dasun Shanaka",
#       "nickName": "Shanaka",
#       "isCaptain": true
#     }, {
#       "id": 10469,
#       "overs": "4",
#       "wickets": 2,
#       "runs": 12,
#       "economy": "3",
#       "name": "Jeffrey Vandersay",
#       "nickName": "Vandersay"
#     }, {
#       "id": 18504,
#       "overs": "4.2",
#       "runs": 25,
#       "economy": "5.8",
#       "name": "Maheesh Theekshana",
#       "nickName": "M Theekshana"
#     }, {
#       "id": 9500,
#       "overs": "1",
#       "runs": 2,
#       "economy": "2",
#       "name": "Chamika Karunaratne",
#       "nickName": "C Karunaratne"
#     }],
#     "fow": [{
#       "fow": [{
#         "batsmanId": 19601,
#         "batsmanName": "Takudzwanashe Kaitano",
#         "overNbr": 9.5,
#         "runs": 59,
#         "ballNbr": 95
#       }, {
#         "batsmanId": 781,
#         "batsmanName": "Regis Chakabva",
#         "overNbr": 15.4,
#         "runs": 90,
#         "ballNbr": 154
#       }]
#     }],
#     "extras": {
#       "legByes": 4,
#       "wides": 2,
#       "noBalls": 1,
#       "total": 7
#     },
#     "pp": [{
#       "powerPlay": [{
#         "id": 33,
#         "ovrFrom": 0.1,
#         "ovrTo": 10.0,
#         "ppType": "mandatory",
#         "run": 59
#       }]
#     }],
#     "score": 101,
#     "wickets": 2,
#     "overs": 18.2,
#     "runRate": 5.51,
#     "batTeamName": "Zimbabwe",
#     "batTeamSName": "ZIM",
#     "ballNbr": 110,
#     "rpb": 0.55
#   }],
#   "appIndex": {
#     "seoTitle": "Cricket scorecard - SL vs ZIM 2nd ODI,Zimbabwe tour of Sri Lanka, 2022 | Cricbuzz.com",
#     "webURL": "http://www.cricbuzz.com/live-cricket-scorecard/42381/sl-vs-zim-2nd-odi-zimbabwe-tour-of-sri-lanka-2022"
#   },
#   "status": "Zimbabwe opt to bat",
#   "responseLastUpdated": "1642501276"
# }

# %%
def GetLastScorecard(match):
    if 'scorecard' not in match:
        return None
    scorecard=match['scorecard']
    lscorecard = len(scorecard)
    if lscorecard <= 0 :
        return None
    
    lastScorecard=scorecard[lscorecard-1]
    return lastScorecard
    
def GetScorecard(match):
    scorecard=GetLastScorecard(match)
    if scorecard is None:
        return ''
    
    score=scorecard['score']
    Wk=scorecard['wickets']
    Ov=scorecard['overs']
    # Rr=latestInn['Rr']
    Team = scorecard['batTeamName']
    Ov="{:.1f}".format(Ov)
    card = f'{Team} {score}/{Wk}  ({Ov} Ov)'
    return card

# %%
scorecard = GetScorecard(match)
print(scorecard)
# Out:
# Zimbabwe 101/2  (18.2 Ov)

# %%
def first_true(iterable, default=False, pred=None):
    return next(filter(pred, iterable), default)
def CallApiGetBowlers(id):
    url = "https://unofficial-cricbuzz.p.rapidapi.com/matches/get-overs"

    querystring = {"matchId":id}

    headers = {
        'x-rapidapi-host': "unofficial-cricbuzz.p.rapidapi.com",
        'x-rapidapi-key': "1eab839b95mshd98f74f1e9e31f4p12c777jsn666802c72f65"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)

    print(response.text)
    return json.loads(response.text)

# %%
oversData = CallApiGetBowlers('42381')
# Out:
# {
#   "miniscore": {
#     "batsmanStriker": {
#       "id": 9494,
#       "balls": 1,
#       "runs": 1,
#       "strkRate": "100",
#       "name": "Kusal Mendis",
#       "nickName": "Kusal Mendis"
#     },
#     "batsmanNonStriker": {
#       "id": 13682,
#       "balls": 11,
#       "runs": 6,
#       "fours": 1,
#       "strkRate": "54.55",
#       "name": "Pathum Nissanka",
#       "nickName": "Pathum Nissanka"
#     },
#     "bowlerStriker": {
#       "id": 6483,
#       "overs": "1",
#       "maidens": 1,
#       "economy": "0",
#       "name": "Tendai Chatara"
#     },
#     "bowlerNonStriker": {
#       "id": 13316,
#       "overs": "1",
#       "runs": 7,
#       "economy": "7",
#       "name": "Blessing Muzarabani"
#     },
#     "crr": 3.5,
#     "rrr": 6.17,
#     "inningsNbr": "1st inn",
#     "curOvsStats": "... 0 0 0 0 0 0  | 1 4 0 2 0 0",
#     "inningsScores": [{
#       "inningsScore": [{
#         "inningsId": 2,
#         "batTeamId": 5,
#         "batTeamShortName": "SL",
#         "runs": 7,
#         "overs": 1.6,
#         "target": 303,
#         "balls": 12
#       }, {
#         "inningsId": 1,
#         "batTeamId": 12,
#         "batTeamShortName": "ZIM",
#         "runs": 302,
#         "wickets": 8,
#         "overs": 49.6,
#         "target": 303,
#         "balls": 300
#       }]
#     }],
#     "inningsId": 2,
#     "partnership": "7(12)",
#     "pp": [{
#       "powerPlay": [{
#         "id": 34,
#         "ovrFrom": 0.1,
#         "ovrTo": 10.0,
#         "ppType": "Mandatory",
#         "run": 7
#       }]
#     }],
#     "target": 303,
#     "custStatus": "Sri Lanka need 296 runs"
#   },
#   "overSepList": [{
#     "overSep": [{
#       "score": 302,
#       "wickets": 8,
#       "inningsId": 1,
#       "overSummary": "1 W 1 B1 2 W ",
#       "runs": 5,
#       "timestamp": "1642509776716",
#       "overNum": 49.6,
#       "ovrBatNames": ["Raza", "Muzarabani", "W Masakadza"],
#       "ovrBowlNames": ["Nuwan Pradeep"],
#       "batTeamName": "ZIM"
#     }, {
#       "score": 297,
#       "wickets": 6,
#       "inningsId": 1,
#       "overSummary": "Wd 4 1 4 2 1 W ",
#       "runs": 13,
#       "timestamp": "1642509426994",
#       "overNum": 48.6,
#       "ovrBatNames": ["Raza", "Ryan Burl"],
#       "ovrBowlNames": ["Dushmantha Chameera"],
#       "batTeamName": "ZIM"
#     }, {
#       "score": 284,
#       "wickets": 5,
#       "inningsId": 1,
#       "overSummary": "4 1 1 1 1 1 ",
#       "runs": 9,
#       "timestamp": "1642509048611",
#       "overNum": 47.6,
#       "ovrBatNames": ["Raza", "Ryan Burl"],
#       "ovrBowlNames": ["Nuwan Pradeep"],
#       "batTeamName": "ZIM"
#     }, {
#       "score": 275,
#       "wickets": 5,
#       "inningsId": 1,
#       "overSummary": "0 1 1 1 0 1 ",
#       "runs": 4,
#       "timestamp": "1642508751109",
#       "overNum": 46.6,
#       "ovrBatNames": ["Raza", "Ryan Burl"],
#       "ovrBowlNames": ["Dushmantha Chameera"],
#       "batTeamName": "ZIM"
#     }, {
#       "score": 271,
#       "wickets": 5,
#       "inningsId": 1,
#       "overSummary": "1 2 0 1 4 1 ",
#       "runs": 9,
#       "timestamp": "1642508478522",
#       "overNum": 45.6,
#       "ovrBatNames": ["Ryan Burl", "Raza"],
#       "ovrBowlNames": ["Nuwan Pradeep"],
#       "batTeamName": "ZIM"
#     }, {
#       "score": 262,
#       "wickets": 5,
#       "inningsId": 1,
#       "overSummary": "1 0 1 2 1 1 ",
#       "runs": 6,
#       "timestamp": "1642508160972",
#       "overNum": 44.6,
#       "ovrBatNames": ["Ryan Burl", "Raza"],
#       "ovrBowlNames": ["Dushmantha Chameera"],
#       "batTeamName": "ZIM"
#     }, {
#       "score": 256,
#       "wickets": 5,
#       "inningsId": 1,
#       "overSummary": "1 2 1 1 W 0 ",
#       "runs": 5,
#       "timestamp": "1642507867219",
#       "overNum": 43.6,
#       "ovrBatNames": ["Ryan Burl", "Ervine", "Raza"],
#       "ovrBowlNames": ["Maheesh Theekshana"],
#       "batTeamName": "ZIM"
#     }, {
#       "score": 251,
#       "wickets": 4,
#       "inningsId": 1,
#       "overSummary": "0 4 L1 4 0 1 ",
#       "runs": 10,
#       "timestamp": "1642507575996",
#       "overNum": 42.6,
#       "ovrBatNames": ["Raza", "Ervine"],
#       "ovrBowlNames": ["Jeffrey Vandersay"],
#       "batTeamName": "ZIM"
#     }, {
#       "score": 241,
#       "wickets": 4,
#       "inningsId": 1,
#       "overSummary": "0 0 1 1 0 1 ",
#       "runs": 3,
#       "timestamp": "1642507382343",
#       "overNum": 41.6,
#       "ovrBatNames": ["Ervine", "Raza"],
#       "ovrBowlNames": ["Maheesh Theekshana"],
#       "batTeamName": "ZIM"
#     }, {
#       "score": 7,
#       "inningsId": 2,
#       "overSummary": "1 4 0 2 0 0 ",
#       "runs": 7,
#       "timestamp": "1642512068121",
#       "overNum": 1.6,
#       "ovrBatNames": ["Nissanka", "Kusal Mendis"],
#       "ovrBowlNames": ["Blessing Muzarabani"],
#       "batTeamName": "SL"
#     }, {
#       "inningsId": 2,
#       "overSummary": "0 0 0 0 0 0 ",
#       "timestamp": "1642511779402",
#       "overNum": 0.6,
#       "ovrBatNames": ["Nissanka", "Kusal Mendis"],
#       "ovrBowlNames": ["Tendai Chatara"],
#       "batTeamName": "SL"
#     }]
#   }],
#   "matchHeaders": {
#     "state": "In Progress",
#     "status": "Sri Lanka need 296 runs",
#     "matchFormat": "ODI",
#     "teamDetails": {
#       "batTeamId": 5,
#       "batTeamName": "SL",
#       "bowlTeamId": 12,
#       "bowlTeamName": "ZIM"
#     }
#   },
#   "responseLastUpdated": "1642512112"
# }

# %%
def GetBowlerStat(bowler):
    name = 'bowler'
    score='0'
    Overs='0'
    wickets='0'
    economy='0'
    
    if bowler is None:
        return f'{name} \n{score}/{wickets} \n({Overs} ov)\n economy {economy}'
    
    if 'name' in bowler:
        name = bowler['name']
    if 'runs' in bowler:
        score = bowler['runs']
    
    if 'overs' in bowler:
        Overs = bowler['overs']
    
    if 'wickets' in bowler:
        wickets = bowler['wickets']
    
    if 'economy' in bowler:
        economy = bowler['economy']
        
    # Economy = bowler['Er']
    card = f'{name} \n{score}/{wickets} \n({Overs} ov)\n economy {economy}'
    return card
def GetBowlerNumber(match,number):
    if match is None:
        return GetBowlerStat(None)
    scorecard = GetLastScorecard(match)
    if 'bowler' not in scorecard:
        return GetBowlerStat(None)
    bowlers = scorecard['bowler']
    if len(bowlers) > number:
        return GetBowlerStat(bowlers[number])
    else:
        return GetBowlerStat(None)
    
        
def GetLastBowler(overs,match=None):
    if 'miniscore' not in overs:
        return GetBowlerNumber(match,0)
    
    miniscore =overs['miniscore']
    
    if 'bowlerStriker' not in miniscore:
        return GetBowlerNumber(match,0)
    
    bowlerStriker = miniscore['bowlerStriker']
    return GetBowlerStat(bowlerStriker)
def GetSecondLastBowler(overs,match=None):
    if 'miniscore' not in overs:
        return GetBowlerNumber(match,1)
    
    miniscore =overs['miniscore']
    
    if 'bowlerNonStriker' not in miniscore:
        return GetBowlerNumber(match,1)
    
    bowlerNonStriker = miniscore['bowlerNonStriker']
    return GetBowlerStat(bowlerNonStriker)

# %%
bowler=GetLastBowler(oversData)
print(bowler)
bowler=GetSecondLastBowler(oversData)
print(bowler)
# Out:
# Dushmantha Chameera
# 24/0
# (6 ov)
#  economy 4
# Maheesh Theekshana
# 38/0
# (7 ov)
#  economy 5.43

# %%
def GetBatsmanStat(batsman):
    name = 'batter'
    runs = 0
    balls = 0
    strkRate=0
    fours = 0
    sixes = 0
    if batsman is None:
        return  f'{name} \n{runs}/{balls} 4({fours}) 6({sixes}) \n sr({strkRate})'
    
    if 'name' in batsman:
        name = batsman['name']
    
    if 'runs' in batsman:
        runs = batsman['runs']
        
    if 'balls' in batsman:
        balls = batsman['balls']
        
    if 'strkRate' in batsman:
        strkRate = batsman['strkRate']
    
    if 'fours' in batsman:
        fours = batsman['fours']
    
    if 'sixes' in batsman:
        sixes = batsman['sixes']
    
    card = f'{name} \n{runs}/{balls} sr({strkRate})\n4({fours}) 6({sixes})'
    return card
def GetBatsmanNumber(match,number):
    if match is None:
        return GetBowlerStat(None)
    scorecard = GetLastScorecard(match)
    if 'batsman' not in scorecard:
        return GetBowlerStat(None)
    batsman = scorecard['batsman']
    if len(batsman) > number:
        return GetBatsmanStat(batsman[number])
    else:
        return GetBatsmanStat(None)
    
def GetBatsman1(overs,match=None):
    if 'miniscore' not in overs:
        return GetBatsmanNumber(match,0)
    
    miniscore =overs['miniscore']
    
    if 'batsmanStriker' not in miniscore:
        return GetBatsmanNumber(match,0)
    
    batsmanStriker = miniscore['batsmanStriker']
    return GetBatsmanStat(batsmanStriker)
def GetBatsman2(overs,match=None):
    if 'miniscore' not in overs:
        return GetBatsmanNumber(match,0)
    
    miniscore =overs['miniscore']
    
    if 'batsmanNonStriker' not in miniscore:
        return GetBatsmanNumber(match,0)
    
    batsmanNonStriker = miniscore['batsmanNonStriker']
    return GetBatsmanStat(batsmanNonStriker)

# %%
bat1=GetBatsman1(oversData)
print(bat1)
bat2=GetBatsman2(oversData)
print(bat2)
# Out:
# Craig Ervine
# 37/44 sr(84.09)
# 4(4) 6(0)
# Sean Williams
# 34/41 sr(82.93)
# 4(3) 6(0)

# %%
def GetProgress(overs):
    if 'miniscore' in overs:
        miniscore = overs['miniscore']
        if 'performance' in miniscore:
            performance = miniscore['performance']
            if len(performance) > 0:
                perform1 = performance[0]
                label = perform1['label']
                runs = perform1['runs']
                return f'{label} : {runs} runs'
    return None
def GetLastBall(overs):
    progress = GetProgress(overs)
    if progress is not None:
        return progress
    else:
        if 'matchHeaders' in overs:
            matchHeaders = overs['matchHeaders']
            if 'state' in matchHeaders:
                state = matchHeaders['state']
                return state
        return ''

# %%
print(GetLastBall(oversData))
# Out:
# Last 5 overs : 28 runs

# %%
def LastOutBatsman(overs):
    if 'miniscore' in overs:
        miniscore = overs['miniscore']
        if 'partnership' in miniscore:
            partnership = miniscore['partnership']
            return partnership
    return ''

# %%
print(LastOutBatsman(oversData))
# Out:
# 61(68)

# %%
def GetLastInning(overs):
    if 'miniscore' not in overs:
        return None
    
    miniscore=overs['miniscore']
    
    
    if 'inningsScores' not in miniscore:
        return None
    
    inningsScores = miniscore['inningsScores']
    
    linningsScores = len(inningsScores)
    if linningsScores <= 0 :
        return None
    
    lastinningsScores=inningsScores[linningsScores-1]
    
    if 'inningsScore' not in lastinningsScores:
        return None
    
    inningsScore = lastinningsScores['inningsScore']
    
    linningsScore = len(inningsScore)
#     print(linningsScore)
    if linningsScore <= 0 :
        return None
    
    
    lastinningsScore=inningsScore[0]
#     print(lastinningsScore)
    return lastinningsScore

def EmptyScoreCard():
    return 'Team 0/0  (0 Ov)'
def GetScorecard(overs):
    lastInning = GetLastInning(overs)
    if lastInning is None:
        return EmptyScoreCard();
    
    runs=0
    wickets=0
    overs=0
    
    if 'runs' in lastInning:
        runs=lastInning['runs']
    if 'wickets' in lastInning:
        wickets=lastInning['wickets']
    if 'overs' in lastInning:
        overs=lastInning['overs']
    
   
    batTeamShortName = lastInning['batTeamShortName']
    
    card = f'{batTeamShortName} {runs}/{wickets}  ({overs} Ov)'
    
    
    return card

# %%
print(GetScorecard(oversData))
# Out:
# SL 7/0  (1.6 Ov)

# %%
def GetTarget(overs):
    lastInning = GetLastInning(overs)
    
    if lastInning is None:
        return 0;
    
    target=0
    if 'target' in lastInning:
        target=lastInning['target']
        
    return target
def GetRunrate(overs):
    if 'miniscore' not in overs:
        return 'Current RR: 0'
    miniscore=overs['miniscore']
    
    crr = 0
    rrr = 0
    if 'crr' in miniscore:
        crr=miniscore['crr']
        
    if 'rrr' in miniscore:
        rrr=miniscore['rrr']
    
    target = GetTarget(overs)
    print(target)
    if rrr == 0 or target == 0:
        return f'Current RR: {crr}'
    else:
        return f'Current RR:{crr} Required RR:{rrr} Target:{target}'
        
    
def GetMatchStatus(overs):
    if 'miniscore' not in overs:
        return ''
    miniscore=overs['miniscore']
    
    if 'custStatus' not in miniscore:
        return ''
    
    custStatus = miniscore['custStatus']
    
    return custStatus

# %%
print(GetRunrate(oversData))
# Out:
# 303
# Current RR: 0
